# %% [markdown]
# # Data Analyst Associate Practical Exam Submission
#
# **You can use any tool that you want to do your analysis and create visualizations. Use this template to write up your summary for submission.**
#
# You can use any markdown formatting you wish. If you are not familiar with Markdown, read the [Markdown Guide](https://s3.amazonaws.com/talent-assets.datacamp.com/Markdown+Guide.pdf) before you start.

# %% [markdown]
# ## Data Validation
# Describe the validation tasks you performed and what you found. Have you made any changes to the data to enable further analysis? Remember to describe what you did for every column in the data.
#
# The original dataset has 879 rows and 9 columns. In the process of following the description, the sales column was converted to numeric by removing the comma and the dollar sign. The next step was the removal of rows not needed for the analysis. The rows that do not contain dogs, cats, fish and bird in the pet type column were dropped. This meant that 46 rows were dropped with 833 rows left. There are no duplicate rows or missing values in the dataset so no values were removed again. The remaining columns have:
#
# 1. There are 879 unique product identifiers
# 2. There are 11 product categories as stated
# 3. There are 5 pet sizes
# 4. The pet type have been reduced to 4 pet types
# 5. Rating is on a 10-point scale
# 6. There are 2 options in the rebuy column 1 or 0, as expected

# %% [markdown]
# ## Data Discovery and Visualization
# Describe what you found in the analysis and how the visualizations answer the customer questions in the project brief. In your description you should:
# - Include at least two different data visualizations to demonstrate the characteristics of single variables
# - Include at least one data visualization to demonstrate the relationship between two or more variables
# - Describe how your analysis has answered the business questions in the project brief
#
# ## How many products are being purchased more than once?
# There are 390 products that were purchased more than once. The most repurchased product category is equipment, which is closely followed by the snack products and toy products. This would indicate that the marketing team should consider equipment and snack products to include in their list of products.
#
# ![Plot showing number of product purchased once and more than once](Plot_1_1.png)
#
# ![Plot showing the product category for repurchased products](Plot_1_2.png)
#
#
#
#
# ## Do the products being purchased again have better sales than others?
# The products purchased once have higher total sales (51125000 dollars) compared to products that were purchased more than once (45587000 dollars). However, products purchased more than once have higher average sales compared to products purchased once. Products in the category of Snacks, toys and supplements that were purchased once have higher total sales than those that were purchased more than once. This could be due to the large prices of these products. The marketing team may want to include these onetime purchase products in their list.
# ![Plot showing total sales for products repurchased once or more than once](Plot_2_1.png)
#
# ![Plot showing sales by products category and repurchased once or more than once](Plot_2_2.png)
#
# ## What products are more likely to be purchased again for different types of pets?
# The products that have been purchased more than once are more likely to be purchased again for different types of pets. For pet dogs and cats, products such equipment, food, medicine, toys and snacks are more likely to be purchased again. Equipment products, snacks and toys are more likely to be repurchased for fish pets. Pet birds have only three possible products that are more likely to be purchased again, these are equipment, toys and snack products. Based on this, equipment products, toy products and snack products should be added to the list of product subscription as they are more likely to be purchased again by customers.
#
# ![Plot showing count of pet types for products purchased more than once](Plot_3.png)
#
# ![Plot showing the Sales by pet type](Plot_3_1.png)
#
# Based on the analysis results, for both product bought once and products repurchased, products in the equipment, toys and snack category are popular among customers as they are the most purchased and bring in the most sales. It is advised that such products be included in the pet box subscription list as they are more likely to be purchased again. Cats and Dogs pet products have the highest sales and the highest number of purchases and should be targeted by the marketing team. Further research should be done to understand customer preferences and other factors that affect product repurchase. The analysis also showed that products purchased once had higher sales in total and higher sales in more categories compared to repurchased products. The marketing team are recommended to include certain products purchased only once in the subscription list.

# %% [markdown]
# ## ✅ When you have finished...
# -  Publish your Workspace using the option on the left
# -  Check the published version of your report:
# 	-  Can you see everything you want us to grade?
#     -  Are all the graphics visible?
# -  Review the grading rubric. Have you included everything that will be graded?
# -  Head back to the [Certification Dashboard](https://app.datacamp.com/certification) to submit your practical exam
